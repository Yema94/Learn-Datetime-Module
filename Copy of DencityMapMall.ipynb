# %%
# !git clone https://github.com/NeuroSYS-pl/objects_counting_dmap.git
# Out:
# Cloning into 'objects_counting_dmap'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 35 (delta 7), reused 6 (delta 6), pack-reused 16
# Unpacking objects: 100% (35/35), done.

# %%
cd objects_counting_dmap/
# Out:
# /content/objects_counting_dmap

# %%
ls
# Out:
# data_loader.py  get_data.py  LICENSE    model.py   requirements.txt
# examples/       infer.py     looper.py  README.md  train.py

# %%
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=e4f08587ef9066661499759010c97062b0e40d181129585c723de8a4143fb914
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...

# %%
# !python get_data.py --dataset mall

# %%
# !python train.py --dataset_name mall --network_architecture UNet --epochs 10 --plot
# Out:
# Epoch 1
#
# <Figure size 640x480 with 4 Axes>
# Train:
# 	Average loss: 0.0818
# 	Mean error: 0.495
# 	Mean absolute error: 11.800
# 	Error deviation: 21.551
# <Figure size 640x480 with 0 Axes>
# Valid:
# 	Average loss: 0.0847
# 	Mean error: -3.319
# 	Mean absolute error: 4.416
# 	Error deviation: 4.408
#
# New best result: 4.415808828125001
#
# --------------------------------------------------------------------------------
#
# Epoch 2
#
# <Figure size 640x480 with 0 Axes>
# Train:
# 	Average loss: 0.0777
# 	Mean error: -1.148
# 	Mean absolute error: 5.306
# 	Error deviation: 6.494
# <Figure size 640x480 with 0 Axes>
# Valid:
# 	Average loss: 0.0830
# 	Mean error: -19.587
# 	Mean absolute error: 19.587
# 	Error deviation: 5.512
#
# --------------------------------------------------------------------------------
#
# Epoch 3
#
# <Figure size 640x480 with 0 Axes>
# Train:
# 	Average loss: 0.0741
# 	Mean error: -0.590
# 	Mean absolute error: 6.181
# 	Error deviation: 7.551
# ...

# %%
# !python infer.py -n UNet -c mall_UNet.pth --image_path /content/objects_counting_dmap/mall_dataset/frames/seq_000001.jpg --visualize
# Out:
# The number of objects found: 30.58368896484375
